# %% [markdown]
# # Apache Spark
#
# ![image.png](data:image/png;base64,...)
#
# ## Przetwarzanie strumieniowe
# ### Operacje na oknach czasowych

# %% [markdown]
# ### Instalacja pakietów

# %%
# !pip install pyspark
# !pip install kafka-python

# %% [markdown]
# ### Pobranie i wystartowanie Kafki

# %%
# !wget https://archive.apache.org/dist/kafka/2.7.0/kafka_2.12-2.7.0.tgz
# !tar -xzf kafka_2.12-2.7.0.tgz
# !rm kafka_2.12-2.7.0.tgz

# %%
import subprocess

# %%
zk = subprocess.Popen(["kafka_2.12-2.7.0/bin/zookeeper-server-start.sh", 
                       "kafka_2.12-2.7.0/config/zookeeper.properties"])

# %%
kf = subprocess.Popen(["kafka_2.12-2.7.0/bin/kafka-server-start.sh", 
                       "kafka_2.12-2.7.0/config/server.properties"])

# %%
# !kafka_2.12-2.7.0/bin/kafka-topics.sh --create --bootstrap-server localhost:9092 --replication-factor 1 --partitions 1 --topic topicX

# %% [markdown]
# ### Wystartowanie producera - żródła danych strumieniowych

# %%
producer = subprocess.Popen(["python", "producer.py"])

# %%
# !kafka_2.12-2.7.0/bin/kafka-console-consumer.sh --bootstrap-server localhost:9092 --topic topicX --from-beginning

# %% [markdown]
# ### Aplikacje

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 1_raw_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 2_simple_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 3_grouping_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 4_simple_sliding_window_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 5_sliding_window_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 6_tumbling_window_app.py

# %%
# !spark-submit --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1 scala_2.12-0.1.jar
